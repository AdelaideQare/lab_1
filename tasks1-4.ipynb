# %% [markdown]
# ## *Задание 1.*
# Работа с ячейками и Markdown

# %% [markdown]
# Практическое занятие №1

# %% [markdown]
# **Караева Аделаида Аладиновна** *ИВТ-б-о-23-1 Вариант 18*

# %% [markdown]
# Нумерованный список мультфильмов:
# 1. Кунг-фу панда
# 2. Гадкий Я
# 3. Губка Боб квадратные штаны

# %% [markdown]
# Список дессертов:
# - Чизкейк
# - Моти
# - Тирамису
# - Пахлава

# %% [markdown]
# **Система уравнений Лагранжа (для оптимизации):**
# $\frac{\partial \mathcal{L}}{\partial x} = 0, \quad \frac{\partial \mathcal{L}}{\partial y} = 0$,
# где $\mathcal{L} = f(x, y) - \lambda g(x, y)$ — лагранжиан.

# %% [markdown]
# ![Кошка учится за компьютером](https://i.pinimg.com/736x/93/b3/77/93b3771064132778e39abee0bbcc3761.jpg)

# %%
name = input()
print(f"Привет, {name}! Добро пожаловать в JupyterLab!")

# %% [markdown]
# ## *Задание 2.*
# Работа с файлами

# %%
import os 
# Создание и запись в файл 
with open("example.txt", "w") as f: 
    f.write("Сегодня суббота\n") 
    f.write("На улице было тепло\n") 
# Чтение файла
with open("example.txt", "r") as f: 
    content = f.read() 
    print("Содержимое файла:\n", content) 
# Проверка существования файла 
print("Файл существует:", os.path.exists("example.txt")) 
# Удаление файла 
os.remove("example.txt") 
print("Файл удален.")
# Out:
# Содержимое файла:
#  Сегодня суббота
# На улице было тепло
#
# Файл существует: True
# Файл удален.

# %% [markdown]
# ## *Задание 3.*
# Магические команды Jupyter

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %time 2**1000
# Out:
# CPU times: user 7 μs, sys: 1e+03 ns, total: 8 μs
# Wall time: 11 μs
# 

# %%
# %%timeit 
sum(range(1000000))
# Out:
# 12.6 ms ± 500 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%writefile math_script.py
import math
x = float(input("Введите число: "))
print(f"Корень: {math.sqrt(x):.2f}")
!python math_script.py
# Out:
# Overwriting math_script.py

# %%
# %ls
# Out:
# lb1.ipynb       math_script.py  table.csv       tasks1.ipynb

# %% [markdown]
# ## Использование history для просмотра истории команд

# %%
# %history
# Out:
# import json
# import getpass
# import hashlib
#
# def import_pandas_safely():
#     try:
#         return __import__('pandas')
#     except ImportError:
#         return False
#
#
# __pandas = import_pandas_safely()
#
#
# def is_data_frame(v: str):
#     obj = eval(v)
#     if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):
#         return True
#
#
# def dataframe_columns(var):
#     df = eval(var)
#     if isinstance(df, __pandas.core.series.Series):
#         return [[df.name, str(df.dtype)]]
#     return list(map(lambda col: [col, str(df[col].dtype)], df.columns))
#
#
# def dtypes_str(frame):
#     return str(eval(frame).dtypes)
#
# def dataframe_hash(var):
#     # Return a hash including the column names and number of rows
#     df = eval(var)
#     if isinstance(df, __pandas.core.series.Series):
#         return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode('utf-8')).hexdigest()
# ...

# %% [markdown]
# ## *Задание 4*
# Взаимодействие с оболочкой системы

# %%
# !ls
# Out:
# lb1.ipynb      math_script.py table.csv      tasks1.ipynb

# %%
# !which python
# Out:
# /opt/anaconda3/bin/python

# %%
# !mkdir test_folder

# %%
# !ls
# Out:
# lb1.ipynb      math_script.py table.csv      tasks1.ipynb   test_folder

# %%
# %%writefile test1.txt
# 1 2 3
# Out:
# Writing test1.txt

# %%
# !mv test1.txt test_folder/

# %%
# !ls test_folder/
# Out:
# test1.txt

# %%
import os
os.remove("test_folder/test1.txt")

# %%
# !clear
